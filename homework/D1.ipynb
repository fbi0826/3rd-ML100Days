# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
def mean_squared_error(y, yp):
    mse = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 211.309
# The Mean absolute error is 11.278

# %%
"""
作業2

Q1. 你選的這組資料為何重要？

A1. 因為此數據可以幫助我們認識雲與氣候的緊密關係。
    
Q2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)

A2. 這些資料是在德國漢堡的Max-Planck-Institite for Meteorite和法國巴黎的Laboratoiredemétéorologiepynamique 的眾包活動中創建的。

一個由68名科學家組成的團隊確定了每幅圖像中的雲圖案區域，每幅圖像都由大約3位不同的科學家進行標記。

在從區域移除任何黑帶區域之後，由該圖像的所有貼標機標記的區域的聯合確定了地面實況。

Q3. 蒐集而來的資料型態為何

A3. 此份資料主要為jpg檔案，是非結構資料。

Q4. 這組資料想解決的問題如何評估

A4.該競賽在平均Dice係數上進行評估。Dice係數可用於比較預測分段與其對應的地面實況之間的逐像素一致性。公式由下式給出：

2 * | X∩ ÿ|| X| + | ÿ|

"""
# Out:
# '\n作業2\n\nQ1. 你選的這組資料為何重要？\n\nA1. 因為此數據可以幫助我們認識雲與氣候的緊密關係。\n    \nQ2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)\n\nA2. 這些資料是在德國漢堡的Max-Planck-Institite for Meteorite和法國巴黎的Laboratoiredemétéorologiepynamique 的眾包活動中創建的。\n\n一個由68名科學家組成的團隊確定了每幅圖像中的雲圖案區域，每幅圖像都由大約3位不同的科學家進行標記。\n\n在從區域移除任何黑帶區域之後，由該圖像的所有貼標機標記的區域的聯合確定了地面實況。\n\nQ3. 蒐集而來的資料型態為何\n\nA3. 此份資料主要為jpg檔案，是非結構資料。\n\nQ4. 這組資料想解決的問題如何評估\n\nA4.該競賽在平均Dice係數上進行評估。Dice係數可用於比較預測分段與其對應的地面實況之間的逐像素一致性。公式由下式給出：\n\n2 * | X∩ ÿ|| X| + | ÿ|\n\n'

# %%
"""

作業三

Q1. 核心問題為何？

A1. 如何增加業績(載客量)

Q2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)

A2. 每日載客量&收入。

Q3. 蒐集而來的資料型態為何

A3. 收集來的資料為數值，是結構資料

Q4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

A4. 設計一函數，確認實踐方法後觀察原載客量與新載客量之關係

"""
# Out:
# '\n\n作業三\n\nQ1. 核心問題為何？\n\nA1. 如何增加業績(載客量)\n\nQ2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)\n\nA2. 每日載客量&收入。\n\nQ3. 蒐集而來的資料型態為何\n\nA3. 收集來的資料為數值，是結構資料\n\nQ4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)\n\nA4. 設計一函數，確認實踐方法後觀察原載客量與新載客量之關係\n\n'
